# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds = pd.read_csv('education_study_vs_score.csv')
ds
# Out:
#    Study_Hours  Test_Score
# 0            1          45
# 1            2          50
# 2            3          55
# 3            4          60
# 4            5          66
# 5            6          70
# 6            7          75
# 7            8          80
# 8            9          85
# 9           10          90

# %%
x=ds[['Study_Hours']]
y=ds[['Test_Score']]

# %%
plt.scatter(x,y)
plt.xlabel('Study_Hours')
plt.ylabel('Test_Score')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
res= reg.predict([[4.5]])
res
# Out:
# array([[62.62837838]])

# %%
ds.columns
# Out:
# Index(['Study_Hours', 'Test_Score'], dtype='object')

# %%
marks= int(input('Enter a hrs for marks prediction : '))
myip= pd.DataFrame(columns=['Study_Hours'], data=[marks])
res= reg.predict(myip)
print('Prediction of marks according study hrs : ',round(res[0,0]))
# Out:
# Enter a hrs for marks prediction :  6
# Prediction of marks according study hrs :  70
